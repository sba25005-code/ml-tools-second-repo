# %% [markdown]
# <a href="https://colab.research.google.com/github/sba25005-code/ml-tools-second-repo/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to the notebook")
# Out:
# welcome to the notebook

# %%
2**10
# Out:
# 1024
